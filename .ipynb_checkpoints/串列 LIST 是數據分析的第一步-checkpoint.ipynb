# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 定義串列LIST

# %%
L = [ 3, 3, 34, 45, 50, 64]

# %%
plot(L)

# %% [markdown]
# ## LIST可以做加減乘除嗎

# %%
K = [ 2, 4, 6, 21, 32]
G = [ 3, 5, 4, 7, 20, 22]

# %%
K + G
# Out:
# [2, 4, 6, 21, 32, 3, 5, 4, 7, 20, 22]

# %%
plot(K+G)

# %% [markdown]
# ## 純量乘法

# %%
L
# Out:
# [3, 3, 34, 45, 50, 64]

# %%
3 * L
# Out:
# [3, 3, 34, 45, 50, 64, 3, 3, 34, 45, 50, 64, 3, 3, 34, 45, 50, 64]
