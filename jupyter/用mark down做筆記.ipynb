# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot([2,7,5,1,9])

# %% [markdown]
# # 大標題
#
# ## 次標題
#
# ### kfd

# %% [markdown]
# ## 分項說明
# * python
# * jupyter

# %% [markdown]
# ## 連結
# [youtube](https://www.youtube.com/)

# %% [markdown]
# ## 插入圖片
# ![派大](patrick.jpg)

# %% [markdown]
# ## 打數學符號
#  我們有一個函數 $f(x)=3x^2+2x+7$ , 我想給它積分
#  $$\int_a^b f(x) \, dx$$
