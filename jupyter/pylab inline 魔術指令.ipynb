# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
tan(pi/3)/sin(pi/2)
# Out:
# 1.7320508075688767

# %%
plot([20, 30, 22, 25, 24, 12, 18, 28])

# %%
randn(6)
# Out:
# array([-0.40099141,  2.74518755, -0.83878956, -0.18737328, -1.50318881,
#        -1.75586829])

# %%
plot(randn(200))

# %%
plot([ 2, 3, 6, 8],[12,10,20,25])

# %%
plot([2,4,6,8])
